# %% [markdown]
# <a href="https://colab.research.google.com/github/vgstaysanonymousport/bulldozer-sales/blob/master/bulldozer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#mounting gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
copied_path = '/content/drive/My Drive/dataset colab/archivetempTrainAndValid.csv'
data = pd.read_csv(copied_path)

# %%
#null data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12419 entries, 0 to 12418
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SalesID                   12419 non-null  int64
#  1   SalePrice                 12419 non-null  int64
#  2   MachineID                 12419 non-null  int64
#  3   ModelID                   12419 non-null  int64
#  4   datasource                12419 non-null  int64
#  5   auctioneerID              12419 non-null  int64
#  6   YearMade                  12419 non-null  int64
#  7   MachineHoursCurrentMeter  12419 non-null  int64
#  8   UsageBand                 10858 non-null  object
#  9   saledate                  12419 non-null  object
#  10  fiModelDesc               12419 non-null  object
#  11  fiBaseModel               12419 non-null  object
#  12  fiSecondaryDesc           8074 non-null   object
# ...

# %%
#plot basic histogram
data.SalePrice.plot.hist()

# %%
data.columns
# Out:
# Index(['SalesID', 'SalePrice', 'MachineID', 'ModelID', 'datasource',
#        'auctioneerID', 'YearMade', 'MachineHoursCurrentMeter', 'UsageBand',
#        'saledate', 'fiModelDesc', 'fiBaseModel', 'fiSecondaryDesc',
#        'fiModelSeries', 'fiModelDescriptor', 'ProductSize',
#        'fiProductClassDesc', 'state', 'ProductGroup', 'ProductGroupDesc',
#        'Drive_System', 'Enclosure', 'Forks', 'Pad_Type', 'Ride_Control',
#        'Stick', 'Transmission', 'Turbocharged', 'Blade_Extension',
#        'Blade_Width', 'Enclosure_Type', 'Engine_Horsepower', 'Hydraulics',
#        'Pushblock', 'Ripper', 'Scarifier', 'Tip_Control', 'Tire_Size',
#        'Coupler', 'Coupler_System', 'Grouser_Tracks', 'Hydraulics_Flow',
#        'Track_Type', 'Undercarriage_Pad_Width', 'Stick_Length', 'Thumb',
#        'Pattern_Changer', 'Grouser_Type', 'Backhoe_Mounting', 'Blade_Type',
#        'Travel_Controls', 'Differential_Type', 'Steering_Controls'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=12419, step=1)

# %%
data.describe()
# Out:
#             SalesID      SalePrice  ...      YearMade  MachineHoursCurrentMeter
# count  1.241900e+04   12419.000000  ...  12419.000000              12419.000000
# mean   1.160003e+06   33893.787664  ...   1863.699090               4241.582172
# std    1.187434e+04   24371.269215  ...    343.194246               5494.205393
# min    1.139246e+06    4750.000000  ...   1000.000000                  0.000000
# 25%    1.149646e+06   15500.000000  ...   1995.000000                800.000000
# 50%    1.160200e+06   26500.000000  ...   2000.000000               2380.000000
# 75%    1.170808e+06   45000.000000  ...   2004.000000               5892.000000
# max    1.179920e+06  142000.000000  ...   2010.000000             141120.000000
#
# [8 rows x 8 columns]

# %%
data['SalePrice'].mean()
# Out:
# 33893.78766406313

# %%
len(data)
# Out:
# 12419

# %%
#location at the index number ''
data.loc[10]
# Out:
# SalesID                                                               1139278
# SalePrice                                                               24000
# MachineID                                                             1024998
# ModelID                                                                  4605
# datasource                                                                121
# auctioneerID                                                                3
# YearMade                                                                 2004
# MachineHoursCurrentMeter                                                 1414
# UsageBand                                                              Medium
# saledate                                                       8/21/2008 0:00
# fiModelDesc                                                              310G
# fiBaseModel                                                               310
# ...

# %%
data['SalePrice'].median
# Out:
# <bound method Series.median of 0        66000
# 1        57000
# 2        10000
# 3        38500
# 4        11000
#          ...
# 12414    94000
# 12415    23500
# 12416    24500
# 12417    45000
# 12418    77000
# Name: SalePrice, Length: 12419, dtype: int64>

# %%
#location of data upto index ''
data.iloc[:10]
# Out:
#    SalesID  SalePrice  ...  Differential_Type  Steering_Controls
# 0  1139246      66000  ...           Standard       Conventional
# 1  1139248      57000  ...           Standard       Conventional
# 2  1139249      10000  ...                NaN                NaN
# 3  1139251      38500  ...                NaN                NaN
# 4  1139253      11000  ...                NaN                NaN
# 5  1139255      26500  ...                NaN                NaN
# 6  1139256      21000  ...                NaN                NaN
# 7  1139261      27000  ...                NaN                NaN
# 8  1139272      21500  ...                NaN                NaN
# 9  1139275      65000  ...           Standard       Conventional
#
# [10 rows x 53 columns]

# %%
data['YearMade'].hist()

# %%
data['Differential_Type'].dtype()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-1917da4ce158> in <module>()
# ----> 1 data['Differential_Type'].dtype()
#
# TypeError: 'numpy.dtype' object is not callable

# %%
data
# Out:
#        SalesID  SalePrice  ...  Differential_Type  Steering_Controls
# 0      1139246      66000  ...           Standard       Conventional
# 1      1139248      57000  ...           Standard       Conventional
# 2      1139249      10000  ...                NaN                NaN
# 3      1139251      38500  ...                NaN                NaN
# 4      1139253      11000  ...                NaN                NaN
# ...        ...        ...  ...                ...                ...
# 12414  1179909      94000  ...           Standard       Conventional
# 12415  1179914      23500  ...           Standard       Conventional
# 12416  1179915      24500  ...           Standard       Conventional
# 12417  1179916      45000  ...                NaN                NaN
# 12418  1179920      77000  ...                NaN                NaN
#
# [12419 rows x 53 columns]

# %%
data = data['Drive_System'].fillna(0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-866ff16645ae> in <module>()
# ----> 1 data = data['Drive_System'].fillna(0, inplace=True)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
data.sample(frac=0.2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-9fb6f49cb269> in <module>()
# ----> 1 data.sample(frac=0.2)
#
# AttributeError: 'NoneType' object has no attribute 'sample'
